# %% [markdown]
# # Whole Code

# %% [markdown]
# ```
# import boto3
#
# REGION = 'us-east-1'
#
# #list all sg
# #find all attched sg
#
# #filter
#
# ec2 = boto3.client('ec2', region_name=REGION)
# def get_all_security_groups() -> list:
#     return [sg.get('GroupId')for sg in ec2.describe_security_groups().get('SecurityGroups')]
#
# def get_attached_security_groups() -> list:
#     base = ec2.describe_instances().get('Reservations')
#     return [i.get('Instances')[0]['SecurityGroups'][0].get('GroupId') for i in base]
#
# #lambda 'group' (this is the input for the anon function) : this is the condition  group not in attached_sg_list
# #filter takes an iterable (list) as the second param and evaluates each against lambda condition
# #checks to see if sg from all listings is in attached
# def filter_unattached_sg() -> list:
#     return list(filter(lambda group: group not in get_attached_security_groups(), get_all_security_groups()))
#
# def delete_unattached_sg(unattached_list):
#     for sg in unattached_list:
#         try:
#             ec2.delete_security_group(GroupId=sg)
#         except Exception as e:
#             if '"default" cannot be deleted by a user' in str(e):
#                 print("Unable to delete default security group")
#
# def init():
#     delete_unattached_sg(filter_unattached_sg())
#
#
#
# if __name__ == "__main__":
#     init()
#
# ```
# #Elliott Arnold boto3 practice delete sg not attached to EC2 instance
# #5-27-22

# %%
import boto3 

REGION = 'us-east-1'

#list all sg 
#find all attched sg
#filter 

ec2 = boto3.client('ec2', region_name=REGION)

# %% [markdown]
# ## ----- Steps for get_all_security_groups()

# %%
ec2.describe_security_groups()
# Out:
# {'SecurityGroups': [{'Description': 'launch-wizard-4 created 2022-03-12T10:44:00.601-05:00',
#    'GroupName': 'launch-wizard-4',
#    'IpPermissions': [{'FromPort': 22,
#      'IpProtocol': 'tcp',
#      'IpRanges': [{'CidrIp': '0.0.0.0/0'}],
#      'Ipv6Ranges': [],
#      'PrefixListIds': [],
#      'ToPort': 22,
#      'UserIdGroupPairs': []},
#     {'FromPort': 3000,
#      'IpProtocol': 'tcp',
#      'IpRanges': [{'CidrIp': '0.0.0.0/0'}],
#      'Ipv6Ranges': [{'CidrIpv6': '::/0'}],
#      'PrefixListIds': [],
#      'ToPort': 3000,
#      'UserIdGroupPairs': []}],
#    'OwnerId': '027940810740',
#    'GroupId': 'sg-0b9ae95a557e9e597',
#    'IpPermissionsEgress': [{'IpProtocol': '-1',
#      'IpRanges': [{'CidrIp': '0.0.0.0/0'}],
#      'Ipv6Ranges': [],
#      'PrefixListIds': [],
#      'UserIdGroupPairs': []}],
#    'VpcId': 'vpc-0ea73b2740360fb3a'},
#   {'Description': 'launch-wizard-2 created 2022-05-27T20:52:01.487Z',
#    'GroupName': 'launch-wizard-2',
#    'IpPermissions': [{'FromPort': 22,
#      'IpProtocol': 'tcp',
#      'IpRanges': [{'CidrIp': '0.0.0.0/0'}],
#      'Ipv6Ranges': [],
#      'PrefixListIds': [],
#      'ToPort': 22,
#      'UserIdGroupPairs': []}],
#    'OwnerId': '027940810740',
#    'GroupId': 'sg-0835e10401540eaf0',
#    'IpPermissionsEgress': [{'IpProtocol': '-1',
#      'IpRanges': [{'CidrIp': '0.0.0.0/0'}],
#      'Ipv6Ranges': [],
#      'PrefixListIds': [],
#      'UserIdGroupPairs': []}],
#    'VpcId': 'vpc-0ea73b2740360fb3a'},
#   {'Description': 'launch-wizard-2 created 2022-03-05T09:08:14.756-05:00',
#    'GroupName': 'launch-wizard-3',
#    'IpPermissions': [{'FromPort': 22,
#      'IpProtocol': 'tcp',
#      'IpRanges': [{'CidrIp': '72.83.222.32/32'}],
#      'Ipv6Ranges': [],
#      'PrefixListIds': [],
#      'ToPort': 22,
#      'UserIdGroupPairs': []}],
#    'OwnerId': '027940810740',
#    'GroupId': 'sg-04136d3c40abbae9e',
#    'IpPermissionsEgress': [{'IpProtocol': '-1',
#      'IpRanges': [{'CidrIp': '0.0.0.0/0'}],
#      'Ipv6Ranges': [],
#      'PrefixListIds': [],
#      'UserIdGroupPairs': []}],
#    'VpcId': 'vpc-0ea73b2740360fb3a'},
#   {'Description': 'launch-wizard created 2022-05-27T20:51:03.270Z',
#    'GroupName': 'launch-wizard-1',
#    'IpPermissions': [{'FromPort': 22,
#      'IpProtocol': 'tcp',
#      'IpRanges': [{'CidrIp': '0.0.0.0/0'}],
#      'Ipv6Ranges': [],
#      'PrefixListIds': [],
#      'ToPort': 22,
#      'UserIdGroupPairs': []}],
#    'OwnerId': '027940810740',
#    'GroupId': 'sg-0ab6bec290e808f90',
#    'IpPermissionsEgress': [{'IpProtocol': '-1',
#      'IpRanges': [{'CidrIp': '0.0.0.0/0'}],
#      'Ipv6Ranges': [],
#      'PrefixListIds': [],
#      'UserIdGroupPairs': []}],
#    'VpcId': 'vpc-0ea73b2740360fb3a'},
#   {'Description': 'default VPC security group',
#    'GroupName': 'default',
#    'IpPermissions': [{'IpProtocol': '-1',
#      'IpRanges': [],
#      'Ipv6Ranges': [],
#      'PrefixListIds': [],
#      'UserIdGroupPairs': [{'GroupId': 'sg-081f6c1a9d9d8cec0',
#        'UserId': '027940810740'}]}],
#    'OwnerId': '027940810740',
#    'GroupId': 'sg-081f6c1a9d9d8cec0',
#    'IpPermissionsEgress': [{'IpProtocol': '-1',
#      'IpRanges': [{'CidrIp': '0.0.0.0/0'}],
#      'Ipv6Ranges': [],
#      'PrefixListIds': [],
#      'UserIdGroupPairs': []}],
#    'VpcId': 'vpc-0ea73b2740360fb3a'},
#   {'Description': 'launch-wizard-5 created 2022-02-22T19:38:18.326-05:00',
#    'GroupName': 'launch-wizard-5',
#    'IpPermissions': [{'FromPort': 80,
#      'IpProtocol': 'tcp',
#      'IpRanges': [{'CidrIp': '72.83.222.32/32'}],
#      'Ipv6Ranges': [],
#      'PrefixListIds': [],
#      'ToPort': 80,
#      'UserIdGroupPairs': []},
#     {'FromPort': 22,
#      'IpProtocol': 'tcp',
#      'IpRanges': [{'CidrIp': '0.0.0.0/0', 'Description': ''}],
#      'Ipv6Ranges': [],
#      'PrefixListIds': [],
#      'ToPort': 22,
#      'UserIdGroupPairs': []}],
#    'OwnerId': '027940810740',
#    'GroupId': 'sg-0ef03ce9260622651',
#    'IpPermissionsEgress': [{'IpProtocol': '-1',
#      'IpRanges': [{'CidrIp': '0.0.0.0/0'}],
#      'Ipv6Ranges': [],
#      'PrefixListIds': [],
#      'UserIdGroupPairs': []}],
#    'VpcId': 'vpc-0ea73b2740360fb3a'}],
#  'ResponseMetadata': {'RequestId': '564820c3-9a01-4532-b4af-f2cdb57dff92',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amzn-requestid': '564820c3-9a01-4532-b4af-f2cdb57dff92',
#    'cache-control': 'no-cache, no-store',
#    'strict-transport-security': 'max-age=31536000; includeSubDomains',
#    'vary': 'accept-encoding',
#    'content-type': 'text/xml;charset=UTF-8',
#    'transfer-encoding': 'chunked',
#    'date': 'Sat, 28 May 2022 17:29:46 GMT',
#    'server': 'AmazonEC2'},
#   'RetryAttempts': 0}}

# %%
ec2.describe_security_groups().get('SecurityGroups')
# Out:
# [{'Description': 'launch-wizard-4 created 2022-03-12T10:44:00.601-05:00',
#   'GroupName': 'launch-wizard-4',
#   'IpPermissions': [{'FromPort': 22,
#     'IpProtocol': 'tcp',
#     'IpRanges': [{'CidrIp': '0.0.0.0/0'}],
#     'Ipv6Ranges': [],
#     'PrefixListIds': [],
#     'ToPort': 22,
#     'UserIdGroupPairs': []},
#    {'FromPort': 3000,
#     'IpProtocol': 'tcp',
#     'IpRanges': [{'CidrIp': '0.0.0.0/0'}],
#     'Ipv6Ranges': [{'CidrIpv6': '::/0'}],
#     'PrefixListIds': [],
#     'ToPort': 3000,
#     'UserIdGroupPairs': []}],
#   'OwnerId': '027940810740',
#   'GroupId': 'sg-0b9ae95a557e9e597',
#   'IpPermissionsEgress': [{'IpProtocol': '-1',
#     'IpRanges': [{'CidrIp': '0.0.0.0/0'}],
#     'Ipv6Ranges': [],
#     'PrefixListIds': [],
#     'UserIdGroupPairs': []}],
#   'VpcId': 'vpc-0ea73b2740360fb3a'},
#  {'Description': 'launch-wizard-2 created 2022-05-27T20:52:01.487Z',
#   'GroupName': 'launch-wizard-2',
#   'IpPermissions': [{'FromPort': 22,
#     'IpProtocol': 'tcp',
#     'IpRanges': [{'CidrIp': '0.0.0.0/0'}],
#     'Ipv6Ranges': [],
#     'PrefixListIds': [],
#     'ToPort': 22,
#     'UserIdGroupPairs': []}],
#   'OwnerId': '027940810740',
#   'GroupId': 'sg-0835e10401540eaf0',
#   'IpPermissionsEgress': [{'IpProtocol': '-1',
#     'IpRanges': [{'CidrIp': '0.0.0.0/0'}],
#     'Ipv6Ranges': [],
#     'PrefixListIds': [],
#     'UserIdGroupPairs': []}],
#   'VpcId': 'vpc-0ea73b2740360fb3a'},
#  {'Description': 'launch-wizard-2 created 2022-03-05T09:08:14.756-05:00',
#   'GroupName': 'launch-wizard-3',
#   'IpPermissions': [{'FromPort': 22,
#     'IpProtocol': 'tcp',
#     'IpRanges': [{'CidrIp': '72.83.222.32/32'}],
#     'Ipv6Ranges': [],
#     'PrefixListIds': [],
#     'ToPort': 22,
#     'UserIdGroupPairs': []}],
#   'OwnerId': '027940810740',
#   'GroupId': 'sg-04136d3c40abbae9e',
#   'IpPermissionsEgress': [{'IpProtocol': '-1',
#     'IpRanges': [{'CidrIp': '0.0.0.0/0'}],
#     'Ipv6Ranges': [],
#     'PrefixListIds': [],
#     'UserIdGroupPairs': []}],
#   'VpcId': 'vpc-0ea73b2740360fb3a'},
#  {'Description': 'launch-wizard created 2022-05-27T20:51:03.270Z',
#   'GroupName': 'launch-wizard-1',
#   'IpPermissions': [{'FromPort': 22,
#     'IpProtocol': 'tcp',
#     'IpRanges': [{'CidrIp': '0.0.0.0/0'}],
#     'Ipv6Ranges': [],
#     'PrefixListIds': [],
#     'ToPort': 22,
#     'UserIdGroupPairs': []}],
#   'OwnerId': '027940810740',
#   'GroupId': 'sg-0ab6bec290e808f90',
#   'IpPermissionsEgress': [{'IpProtocol': '-1',
#     'IpRanges': [{'CidrIp': '0.0.0.0/0'}],
#     'Ipv6Ranges': [],
#     'PrefixListIds': [],
#     'UserIdGroupPairs': []}],
#   'VpcId': 'vpc-0ea73b2740360fb3a'},
#  {'Description': 'default VPC security group',
#   'GroupName': 'default',
#   'IpPermissions': [{'IpProtocol': '-1',
#     'IpRanges': [],
#     'Ipv6Ranges': [],
#     'PrefixListIds': [],
#     'UserIdGroupPairs': [{'GroupId': 'sg-081f6c1a9d9d8cec0',
#       'UserId': '027940810740'}]}],
#   'OwnerId': '027940810740',
#   'GroupId': 'sg-081f6c1a9d9d8cec0',
#   'IpPermissionsEgress': [{'IpProtocol': '-1',
#     'IpRanges': [{'CidrIp': '0.0.0.0/0'}],
#     'Ipv6Ranges': [],
#     'PrefixListIds': [],
#     'UserIdGroupPairs': []}],
#   'VpcId': 'vpc-0ea73b2740360fb3a'},
#  {'Description': 'launch-wizard-5 created 2022-02-22T19:38:18.326-05:00',
#   'GroupName': 'launch-wizard-5',
#   'IpPermissions': [{'FromPort': 80,
#     'IpProtocol': 'tcp',
#     'IpRanges': [{'CidrIp': '72.83.222.32/32'}],
#     'Ipv6Ranges': [],
#     'PrefixListIds': [],
#     'ToPort': 80,
#     'UserIdGroupPairs': []},
#    {'FromPort': 22,
#     'IpProtocol': 'tcp',
#     'IpRanges': [{'CidrIp': '0.0.0.0/0', 'Description': ''}],
#     'Ipv6Ranges': [],
#     'PrefixListIds': [],
#     'ToPort': 22,
#     'UserIdGroupPairs': []}],
#   'OwnerId': '027940810740',
#   'GroupId': 'sg-0ef03ce9260622651',
#   'IpPermissionsEgress': [{'IpProtocol': '-1',
#     'IpRanges': [{'CidrIp': '0.0.0.0/0'}],
#     'Ipv6Ranges': [],
#     'PrefixListIds': [],
#     'UserIdGroupPairs': []}],
#   'VpcId': 'vpc-0ea73b2740360fb3a'}]

# %%
[sg.get('GroupId') for sg in ec2.describe_security_groups().get('SecurityGroups')]
# Out:
# ['sg-0b9ae95a557e9e597',
#  'sg-0835e10401540eaf0',
#  'sg-04136d3c40abbae9e',
#  'sg-0ab6bec290e808f90',
#  'sg-081f6c1a9d9d8cec0',
#  'sg-0ef03ce9260622651']

# %%
def get_all_security_groups() -> list:
    return [sg.get('GroupId')for sg in ec2.describe_security_groups().get('SecurityGroups')]

# %%
get_all_security_groups()
# Out:
# ['sg-0b9ae95a557e9e597',
#  'sg-0835e10401540eaf0',
#  'sg-04136d3c40abbae9e',
#  'sg-0ab6bec290e808f90',
#  'sg-081f6c1a9d9d8cec0',
#  'sg-0ef03ce9260622651']

# %% [markdown]
# ## ----- Steps for get_attached_security_groups()

# %%
base = ec2.describe_instances().get('Reservations')
display(base)
# Out:
# [{'Groups': [],
#   'Instances': [{'AmiLaunchIndex': 0,
#     'ImageId': 'ami-04505e74c0741db8d',
#     'InstanceId': 'i-076a1b73343c764b3',
#     'InstanceType': 't2.micro',
#     'KeyName': 'Project2InstanceKeyPair',
#     'LaunchTime': datetime.datetime(2022, 3, 12, 19, 22, 8, tzinfo=tzutc()),
#     'Monitoring': {'State': 'disabled'},
#     'Placement': {'AvailabilityZone': 'us-east-1c',
#      'GroupName': '',
#      'Tenancy': 'default'},
#     'PrivateDnsName': 'ip-172-31-82-10.ec2.internal',
#     'PrivateIpAddress': '172.31.82.10',
#     'ProductCodes': [],
#     'PublicDnsName': '',
#     'State': {'Code': 80, 'Name': 'stopped'},
#     'StateTransitionReason': 'User initiated (2022-03-12 22:33:57 GMT)',
#     'SubnetId': 'subnet-0561535e87be09b43',
#     'VpcId': 'vpc-0ea73b2740360fb3a',
#     'Architecture': 'x86_64',
#     'BlockDeviceMappings': [{'DeviceName': '/dev/sda1',
#       'Ebs': {'AttachTime': datetime.datetime(2022, 3, 12, 19, 22, 9, tzinfo=tzutc()),
#        'DeleteOnTermination': True,
#        'Status': 'attached',
#        'VolumeId': 'vol-02065c982220b3baf'}}],
#     'ClientToken': '',
#     'EbsOptimized': False,
#     'EnaSupport': True,
#     'Hypervisor': 'xen',
#     'IamInstanceProfile': {'Arn': 'arn:aws:iam::027940810740:instance-profile/ec2adminrole',
#      'Id': 'AIPAQNALG572LHRDGALYW'},
#     'NetworkInterfaces': [{'Attachment': {'AttachTime': datetime.datetime(2022, 3, 12, 19, 22, 8, tzinfo=tzutc()),
#        'AttachmentId': 'eni-attach-0d7dcdfc3e8b032ca',
#        'DeleteOnTermination': True,
#        'DeviceIndex': 0,
#        'Status': 'attached',
#        'NetworkCardIndex': 0},
#       'Description': '',
#       'Groups': [{'GroupName': 'launch-wizard-4',
#         'GroupId': 'sg-0b9ae95a557e9e597'}],
#       'Ipv6Addresses': [],
#       'MacAddress': '12:cb:ab:95:73:65',
#       'NetworkInterfaceId': 'eni-01989684751372788',
#       'OwnerId': '027940810740',
#       'PrivateDnsName': 'ip-172-31-82-10.ec2.internal',
#       'PrivateIpAddress': '172.31.82.10',
#       'PrivateIpAddresses': [{'Primary': True,
#         'PrivateDnsName': 'ip-172-31-82-10.ec2.internal',
#         'PrivateIpAddress': '172.31.82.10'}],
#       'SourceDestCheck': True,
#       'Status': 'in-use',
#       'SubnetId': 'subnet-0561535e87be09b43',
#       'VpcId': 'vpc-0ea73b2740360fb3a',
#       'InterfaceType': 'interface'}],
#     'RootDeviceName': '/dev/sda1',
#     'RootDeviceType': 'ebs',
#     'SecurityGroups': [{'GroupName': 'launch-wizard-4',
#       'GroupId': 'sg-0b9ae95a557e9e597'}],
#     'SourceDestCheck': True,
#     'StateReason': {'Code': 'Client.UserInitiatedShutdown',
#      'Message': 'Client.UserInitiatedShutdown: User initiated shutdown'},
#     'Tags': [{'Key': 'Delpoymentgroup', 'Value': 'workshop'},
#      {'Key': 'Name', 'Value': 'CICDinstance'}],
#     'VirtualizationType': 'hvm',
#     'CpuOptions': {'CoreCount': 1, 'ThreadsPerCore': 1},
#     'CapacityReservationSpecification': {'CapacityReservationPreference': 'open'},
#     'HibernationOptions': {'Configured': False},
#     'MetadataOptions': {'State': 'applied',
#      'HttpTokens': 'optional',
#      'HttpPutResponseHopLimit': 1,
#      'HttpEndpoint': 'enabled',
#      'HttpProtocolIpv6': 'disabled',
#      'InstanceMetadataTags': 'disabled'},
#     'EnclaveOptions': {'Enabled': False},
#     'PlatformDetails': 'Linux/UNIX',
#     'UsageOperation': 'RunInstances',
#     'UsageOperationUpdateTime': datetime.datetime(2022, 3, 12, 19, 22, 8, tzinfo=tzutc()),
#     'PrivateDnsNameOptions': {'HostnameType': 'ip-name',
#      'EnableResourceNameDnsARecord': True,
#      'EnableResourceNameDnsAAAARecord': False},
#     'MaintenanceOptions': {'AutoRecovery': 'default'}}],
#   'OwnerId': '027940810740',
#   'ReservationId': 'r-006930c794bf60ac3'},
#  {'Groups': [],
#   'Instances': [{'AmiLaunchIndex': 0,
#     'ImageId': 'ami-0022f774911c1d690',
#     'InstanceId': 'i-0512fcadf0e21c998',
#     'InstanceType': 't2.micro',
#     'KeyName': 'test',
#     'LaunchTime': datetime.datetime(2022, 5, 27, 20, 52, 26, tzinfo=tzutc()),
#     'Monitoring': {'State': 'disabled'},
#     'Placement': {'AvailabilityZone': 'us-east-1d',
#      'GroupName': '',
#      'Tenancy': 'default'},
#     'PrivateDnsName': 'ip-172-31-21-84.ec2.internal',
#     'PrivateIpAddress': '172.31.21.84',
#     'ProductCodes': [],
#     'PublicDnsName': 'ec2-54-160-230-244.compute-1.amazonaws.com',
#     'PublicIpAddress': '54.160.230.244',
#     'State': {'Code': 16, 'Name': 'running'},
#     'StateTransitionReason': '',
#     'SubnetId': 'subnet-087f3c89ac49c4386',
#     'VpcId': 'vpc-0ea73b2740360fb3a',
#     'Architecture': 'x86_64',
#     'BlockDeviceMappings': [{'DeviceName': '/dev/xvda',
#       'Ebs': {'AttachTime': datetime.datetime(2022, 5, 27, 20, 52, 27, tzinfo=tzutc()),
#        'DeleteOnTermination': True,
#        'Status': 'attached',
#        'VolumeId': 'vol-0097f66834a5037aa'}}],
#     'ClientToken': '',
#     'EbsOptimized': False,
#     'EnaSupport': True,
#     'Hypervisor': 'xen',
#     'NetworkInterfaces': [{'Association': {'IpOwnerId': 'amazon',
#        'PublicDnsName': 'ec2-54-160-230-244.compute-1.amazonaws.com',
#        'PublicIp': '54.160.230.244'},
#       'Attachment': {'AttachTime': datetime.datetime(2022, 5, 27, 20, 52, 26, tzinfo=tzutc()),
#        'AttachmentId': 'eni-attach-059a9ba9bd9150eb2',
#        'DeleteOnTermination': True,
#        'DeviceIndex': 0,
#        'Status': 'attached',
#        'NetworkCardIndex': 0},
#       'Description': '',
#       'Groups': [{'GroupName': 'launch-wizard-2',
#         'GroupId': 'sg-0835e10401540eaf0'}],
#       'Ipv6Addresses': [],
#       'MacAddress': '0a:85:6f:2c:37:8d',
#       'NetworkInterfaceId': 'eni-067569c6c7bed1ccb',
#       'OwnerId': '027940810740',
#       'PrivateDnsName': 'ip-172-31-21-84.ec2.internal',
#       'PrivateIpAddress': '172.31.21.84',
#       'PrivateIpAddresses': [{'Association': {'IpOwnerId': 'amazon',
#          'PublicDnsName': 'ec2-54-160-230-244.compute-1.amazonaws.com',
#          'PublicIp': '54.160.230.244'},
#         'Primary': True,
#         'PrivateDnsName': 'ip-172-31-21-84.ec2.internal',
#         'PrivateIpAddress': '172.31.21.84'}],
#       'SourceDestCheck': True,
#       'Status': 'in-use',
#       'SubnetId': 'subnet-087f3c89ac49c4386',
#       'VpcId': 'vpc-0ea73b2740360fb3a',
#       'InterfaceType': 'interface'}],
#     'RootDeviceName': '/dev/xvda',
#     'RootDeviceType': 'ebs',
#     'SecurityGroups': [{'GroupName': 'launch-wizard-2',
#       'GroupId': 'sg-0835e10401540eaf0'}],
#     'SourceDestCheck': True,
#     'Tags': [{'Key': 'Name', 'Value': 'test2'}],
#     'VirtualizationType': 'hvm',
#     'CpuOptions': {'CoreCount': 1, 'ThreadsPerCore': 1},
#     'CapacityReservationSpecification': {'CapacityReservationPreference': 'open'},
#     'HibernationOptions': {'Configured': False},
#     'MetadataOptions': {'State': 'applied',
#      'HttpTokens': 'optional',
#      'HttpPutResponseHopLimit': 1,
#      'HttpEndpoint': 'enabled',
#      'HttpProtocolIpv6': 'disabled',
#      'InstanceMetadataTags': 'disabled'},
#     'EnclaveOptions': {'Enabled': False},
#     'PlatformDetails': 'Linux/UNIX',
#     'UsageOperation': 'RunInstances',
#     'UsageOperationUpdateTime': datetime.datetime(2022, 5, 27, 20, 52, 26, tzinfo=tzutc()),
#     'PrivateDnsNameOptions': {'HostnameType': 'ip-name',
#      'EnableResourceNameDnsARecord': True,
#      'EnableResourceNameDnsAAAARecord': False},
#     'MaintenanceOptions': {'AutoRecovery': 'default'}}],
#   'OwnerId': '027940810740',
#   'ReservationId': 'r-0e5996c939576778d'},
#  {'Groups': [],
#   'Instances': [{'AmiLaunchIndex': 0,
#     'ImageId': 'ami-0022f774911c1d690',
#     'InstanceId': 'i-0d2cacb57098bec65',
#     'InstanceType': 't2.micro',
#     'KeyName': 'test',
#     'LaunchTime': datetime.datetime(2022, 5, 27, 20, 51, 51, tzinfo=tzutc()),
#     'Monitoring': {'State': 'disabled'},
#     'Placement': {'AvailabilityZone': 'us-east-1d',
#      'GroupName': '',
#      'Tenancy': 'default'},
#     'PrivateDnsName': 'ip-172-31-31-220.ec2.internal',
#     'PrivateIpAddress': '172.31.31.220',
#     'ProductCodes': [],
#     'PublicDnsName': 'ec2-34-207-151-86.compute-1.amazonaws.com',
#     'PublicIpAddress': '34.207.151.86',
#     'State': {'Code': 16, 'Name': 'running'},
#     'StateTransitionReason': '',
#     'SubnetId': 'subnet-087f3c89ac49c4386',
#     'VpcId': 'vpc-0ea73b2740360fb3a',
#     'Architecture': 'x86_64',
#     'BlockDeviceMappings': [{'DeviceName': '/dev/xvda',
#       'Ebs': {'AttachTime': datetime.datetime(2022, 5, 27, 20, 51, 51, tzinfo=tzutc()),
#        'DeleteOnTermination': True,
#        'Status': 'attached',
#        'VolumeId': 'vol-09e77dc138da31c95'}}],
#     'ClientToken': '',
#     'EbsOptimized': False,
#     'EnaSupport': True,
#     'Hypervisor': 'xen',
#     'NetworkInterfaces': [{'Association': {'IpOwnerId': 'amazon',
#        'PublicDnsName': 'ec2-34-207-151-86.compute-1.amazonaws.com',
#        'PublicIp': '34.207.151.86'},
#       'Attachment': {'AttachTime': datetime.datetime(2022, 5, 27, 20, 51, 51, tzinfo=tzutc()),
#        'AttachmentId': 'eni-attach-0d20fbff5fda18c7a',
#        'DeleteOnTermination': True,
#        'DeviceIndex': 0,
#        'Status': 'attached',
#        'NetworkCardIndex': 0},
#       'Description': '',
#       'Groups': [{'GroupName': 'launch-wizard-1',
#         'GroupId': 'sg-0ab6bec290e808f90'}],
#       'Ipv6Addresses': [],
#       'MacAddress': '0a:8c:0f:5b:e7:7d',
#       'NetworkInterfaceId': 'eni-0d3085b6105aa07e9',
#       'OwnerId': '027940810740',
#       'PrivateDnsName': 'ip-172-31-31-220.ec2.internal',
#       'PrivateIpAddress': '172.31.31.220',
#       'PrivateIpAddresses': [{'Association': {'IpOwnerId': 'amazon',
#          'PublicDnsName': 'ec2-34-207-151-86.compute-1.amazonaws.com',
#          'PublicIp': '34.207.151.86'},
#         'Primary': True,
#         'PrivateDnsName': 'ip-172-31-31-220.ec2.internal',
#         'PrivateIpAddress': '172.31.31.220'}],
#       'SourceDestCheck': True,
#       'Status': 'in-use',
#       'SubnetId': 'subnet-087f3c89ac49c4386',
#       'VpcId': 'vpc-0ea73b2740360fb3a',
#       'InterfaceType': 'interface'}],
#     'RootDeviceName': '/dev/xvda',
#     'RootDeviceType': 'ebs',
#     'SecurityGroups': [{'GroupName': 'launch-wizard-1',
#       'GroupId': 'sg-0ab6bec290e808f90'}],
#     'SourceDestCheck': True,
#     'Tags': [{'Key': 'Name', 'Value': 'test_instance'}],
#     'VirtualizationType': 'hvm',
#     'CpuOptions': {'CoreCount': 1, 'ThreadsPerCore': 1},
#     'CapacityReservationSpecification': {'CapacityReservationPreference': 'open'},
#     'HibernationOptions': {'Configured': False},
#     'MetadataOptions': {'State': 'applied',
#      'HttpTokens': 'optional',
#      'HttpPutResponseHopLimit': 1,
#      'HttpEndpoint': 'enabled',
#      'HttpProtocolIpv6': 'disabled',
#      'InstanceMetadataTags': 'disabled'},
#     'EnclaveOptions': {'Enabled': False},
#     'PlatformDetails': 'Linux/UNIX',
#     'UsageOperation': 'RunInstances',
#     'UsageOperationUpdateTime': datetime.datetime(2022, 5, 27, 20, 51, 51, tzinfo=tzutc()),
#     'PrivateDnsNameOptions': {'HostnameType': 'ip-name',
#      'EnableResourceNameDnsARecord': True,
#      'EnableResourceNameDnsAAAARecord': False},
#     'MaintenanceOptions': {'AutoRecovery': 'default'}}],
#   'OwnerId': '027940810740',
#   'ReservationId': 'r-005a387227b8e194f'}]

# %%
[i.get('Instances')[0] for i in base]
# Out:
# [{'AmiLaunchIndex': 0,
#   'ImageId': 'ami-04505e74c0741db8d',
#   'InstanceId': 'i-076a1b73343c764b3',
#   'InstanceType': 't2.micro',
#   'KeyName': 'Project2InstanceKeyPair',
#   'LaunchTime': datetime.datetime(2022, 3, 12, 19, 22, 8, tzinfo=tzutc()),
#   'Monitoring': {'State': 'disabled'},
#   'Placement': {'AvailabilityZone': 'us-east-1c',
#    'GroupName': '',
#    'Tenancy': 'default'},
#   'PrivateDnsName': 'ip-172-31-82-10.ec2.internal',
#   'PrivateIpAddress': '172.31.82.10',
#   'ProductCodes': [],
#   'PublicDnsName': '',
#   'State': {'Code': 80, 'Name': 'stopped'},
#   'StateTransitionReason': 'User initiated (2022-03-12 22:33:57 GMT)',
#   'SubnetId': 'subnet-0561535e87be09b43',
#   'VpcId': 'vpc-0ea73b2740360fb3a',
#   'Architecture': 'x86_64',
#   'BlockDeviceMappings': [{'DeviceName': '/dev/sda1',
#     'Ebs': {'AttachTime': datetime.datetime(2022, 3, 12, 19, 22, 9, tzinfo=tzutc()),
#      'DeleteOnTermination': True,
#      'Status': 'attached',
#      'VolumeId': 'vol-02065c982220b3baf'}}],
#   'ClientToken': '',
#   'EbsOptimized': False,
#   'EnaSupport': True,
#   'Hypervisor': 'xen',
#   'IamInstanceProfile': {'Arn': 'arn:aws:iam::027940810740:instance-profile/ec2adminrole',
#    'Id': 'AIPAQNALG572LHRDGALYW'},
#   'NetworkInterfaces': [{'Attachment': {'AttachTime': datetime.datetime(2022, 3, 12, 19, 22, 8, tzinfo=tzutc()),
#      'AttachmentId': 'eni-attach-0d7dcdfc3e8b032ca',
#      'DeleteOnTermination': True,
#      'DeviceIndex': 0,
#      'Status': 'attached',
#      'NetworkCardIndex': 0},
#     'Description': '',
#     'Groups': [{'GroupName': 'launch-wizard-4',
#       'GroupId': 'sg-0b9ae95a557e9e597'}],
#     'Ipv6Addresses': [],
#     'MacAddress': '12:cb:ab:95:73:65',
#     'NetworkInterfaceId': 'eni-01989684751372788',
#     'OwnerId': '027940810740',
#     'PrivateDnsName': 'ip-172-31-82-10.ec2.internal',
#     'PrivateIpAddress': '172.31.82.10',
#     'PrivateIpAddresses': [{'Primary': True,
#       'PrivateDnsName': 'ip-172-31-82-10.ec2.internal',
#       'PrivateIpAddress': '172.31.82.10'}],
#     'SourceDestCheck': True,
#     'Status': 'in-use',
#     'SubnetId': 'subnet-0561535e87be09b43',
#     'VpcId': 'vpc-0ea73b2740360fb3a',
#     'InterfaceType': 'interface'}],
#   'RootDeviceName': '/dev/sda1',
#   'RootDeviceType': 'ebs',
#   'SecurityGroups': [{'GroupName': 'launch-wizard-4',
#     'GroupId': 'sg-0b9ae95a557e9e597'}],
#   'SourceDestCheck': True,
#   'StateReason': {'Code': 'Client.UserInitiatedShutdown',
#    'Message': 'Client.UserInitiatedShutdown: User initiated shutdown'},
#   'Tags': [{'Key': 'Delpoymentgroup', 'Value': 'workshop'},
#    {'Key': 'Name', 'Value': 'CICDinstance'}],
#   'VirtualizationType': 'hvm',
#   'CpuOptions': {'CoreCount': 1, 'ThreadsPerCore': 1},
#   'CapacityReservationSpecification': {'CapacityReservationPreference': 'open'},
#   'HibernationOptions': {'Configured': False},
#   'MetadataOptions': {'State': 'applied',
#    'HttpTokens': 'optional',
#    'HttpPutResponseHopLimit': 1,
#    'HttpEndpoint': 'enabled',
#    'HttpProtocolIpv6': 'disabled',
#    'InstanceMetadataTags': 'disabled'},
#   'EnclaveOptions': {'Enabled': False},
#   'PlatformDetails': 'Linux/UNIX',
#   'UsageOperation': 'RunInstances',
#   'UsageOperationUpdateTime': datetime.datetime(2022, 3, 12, 19, 22, 8, tzinfo=tzutc()),
#   'PrivateDnsNameOptions': {'HostnameType': 'ip-name',
#    'EnableResourceNameDnsARecord': True,
#    'EnableResourceNameDnsAAAARecord': False},
#   'MaintenanceOptions': {'AutoRecovery': 'default'}},
#  {'AmiLaunchIndex': 0,
#   'ImageId': 'ami-0022f774911c1d690',
#   'InstanceId': 'i-0512fcadf0e21c998',
#   'InstanceType': 't2.micro',
#   'KeyName': 'test',
#   'LaunchTime': datetime.datetime(2022, 5, 27, 20, 52, 26, tzinfo=tzutc()),
#   'Monitoring': {'State': 'disabled'},
#   'Placement': {'AvailabilityZone': 'us-east-1d',
#    'GroupName': '',
#    'Tenancy': 'default'},
#   'PrivateDnsName': 'ip-172-31-21-84.ec2.internal',
#   'PrivateIpAddress': '172.31.21.84',
#   'ProductCodes': [],
#   'PublicDnsName': 'ec2-54-160-230-244.compute-1.amazonaws.com',
#   'PublicIpAddress': '54.160.230.244',
#   'State': {'Code': 16, 'Name': 'running'},
#   'StateTransitionReason': '',
#   'SubnetId': 'subnet-087f3c89ac49c4386',
#   'VpcId': 'vpc-0ea73b2740360fb3a',
#   'Architecture': 'x86_64',
#   'BlockDeviceMappings': [{'DeviceName': '/dev/xvda',
#     'Ebs': {'AttachTime': datetime.datetime(2022, 5, 27, 20, 52, 27, tzinfo=tzutc()),
#      'DeleteOnTermination': True,
#      'Status': 'attached',
#      'VolumeId': 'vol-0097f66834a5037aa'}}],
#   'ClientToken': '',
#   'EbsOptimized': False,
#   'EnaSupport': True,
#   'Hypervisor': 'xen',
#   'NetworkInterfaces': [{'Association': {'IpOwnerId': 'amazon',
#      'PublicDnsName': 'ec2-54-160-230-244.compute-1.amazonaws.com',
#      'PublicIp': '54.160.230.244'},
#     'Attachment': {'AttachTime': datetime.datetime(2022, 5, 27, 20, 52, 26, tzinfo=tzutc()),
#      'AttachmentId': 'eni-attach-059a9ba9bd9150eb2',
#      'DeleteOnTermination': True,
#      'DeviceIndex': 0,
#      'Status': 'attached',
#      'NetworkCardIndex': 0},
#     'Description': '',
#     'Groups': [{'GroupName': 'launch-wizard-2',
#       'GroupId': 'sg-0835e10401540eaf0'}],
#     'Ipv6Addresses': [],
#     'MacAddress': '0a:85:6f:2c:37:8d',
#     'NetworkInterfaceId': 'eni-067569c6c7bed1ccb',
#     'OwnerId': '027940810740',
#     'PrivateDnsName': 'ip-172-31-21-84.ec2.internal',
#     'PrivateIpAddress': '172.31.21.84',
#     'PrivateIpAddresses': [{'Association': {'IpOwnerId': 'amazon',
#        'PublicDnsName': 'ec2-54-160-230-244.compute-1.amazonaws.com',
#        'PublicIp': '54.160.230.244'},
#       'Primary': True,
#       'PrivateDnsName': 'ip-172-31-21-84.ec2.internal',
#       'PrivateIpAddress': '172.31.21.84'}],
#     'SourceDestCheck': True,
#     'Status': 'in-use',
#     'SubnetId': 'subnet-087f3c89ac49c4386',
#     'VpcId': 'vpc-0ea73b2740360fb3a',
#     'InterfaceType': 'interface'}],
#   'RootDeviceName': '/dev/xvda',
#   'RootDeviceType': 'ebs',
#   'SecurityGroups': [{'GroupName': 'launch-wizard-2',
#     'GroupId': 'sg-0835e10401540eaf0'}],
#   'SourceDestCheck': True,
#   'Tags': [{'Key': 'Name', 'Value': 'test2'}],
#   'VirtualizationType': 'hvm',
#   'CpuOptions': {'CoreCount': 1, 'ThreadsPerCore': 1},
#   'CapacityReservationSpecification': {'CapacityReservationPreference': 'open'},
#   'HibernationOptions': {'Configured': False},
#   'MetadataOptions': {'State': 'applied',
#    'HttpTokens': 'optional',
#    'HttpPutResponseHopLimit': 1,
#    'HttpEndpoint': 'enabled',
#    'HttpProtocolIpv6': 'disabled',
#    'InstanceMetadataTags': 'disabled'},
#   'EnclaveOptions': {'Enabled': False},
#   'PlatformDetails': 'Linux/UNIX',
#   'UsageOperation': 'RunInstances',
#   'UsageOperationUpdateTime': datetime.datetime(2022, 5, 27, 20, 52, 26, tzinfo=tzutc()),
#   'PrivateDnsNameOptions': {'HostnameType': 'ip-name',
#    'EnableResourceNameDnsARecord': True,
#    'EnableResourceNameDnsAAAARecord': False},
#   'MaintenanceOptions': {'AutoRecovery': 'default'}},
#  {'AmiLaunchIndex': 0,
#   'ImageId': 'ami-0022f774911c1d690',
#   'InstanceId': 'i-0d2cacb57098bec65',
#   'InstanceType': 't2.micro',
#   'KeyName': 'test',
#   'LaunchTime': datetime.datetime(2022, 5, 27, 20, 51, 51, tzinfo=tzutc()),
#   'Monitoring': {'State': 'disabled'},
#   'Placement': {'AvailabilityZone': 'us-east-1d',
#    'GroupName': '',
#    'Tenancy': 'default'},
#   'PrivateDnsName': 'ip-172-31-31-220.ec2.internal',
#   'PrivateIpAddress': '172.31.31.220',
#   'ProductCodes': [],
#   'PublicDnsName': 'ec2-34-207-151-86.compute-1.amazonaws.com',
#   'PublicIpAddress': '34.207.151.86',
#   'State': {'Code': 16, 'Name': 'running'},
#   'StateTransitionReason': '',
#   'SubnetId': 'subnet-087f3c89ac49c4386',
#   'VpcId': 'vpc-0ea73b2740360fb3a',
#   'Architecture': 'x86_64',
#   'BlockDeviceMappings': [{'DeviceName': '/dev/xvda',
#     'Ebs': {'AttachTime': datetime.datetime(2022, 5, 27, 20, 51, 51, tzinfo=tzutc()),
#      'DeleteOnTermination': True,
#      'Status': 'attached',
#      'VolumeId': 'vol-09e77dc138da31c95'}}],
#   'ClientToken': '',
#   'EbsOptimized': False,
#   'EnaSupport': True,
#   'Hypervisor': 'xen',
#   'NetworkInterfaces': [{'Association': {'IpOwnerId': 'amazon',
#      'PublicDnsName': 'ec2-34-207-151-86.compute-1.amazonaws.com',
#      'PublicIp': '34.207.151.86'},
#     'Attachment': {'AttachTime': datetime.datetime(2022, 5, 27, 20, 51, 51, tzinfo=tzutc()),
#      'AttachmentId': 'eni-attach-0d20fbff5fda18c7a',
#      'DeleteOnTermination': True,
#      'DeviceIndex': 0,
#      'Status': 'attached',
#      'NetworkCardIndex': 0},
#     'Description': '',
#     'Groups': [{'GroupName': 'launch-wizard-1',
#       'GroupId': 'sg-0ab6bec290e808f90'}],
#     'Ipv6Addresses': [],
#     'MacAddress': '0a:8c:0f:5b:e7:7d',
#     'NetworkInterfaceId': 'eni-0d3085b6105aa07e9',
#     'OwnerId': '027940810740',
#     'PrivateDnsName': 'ip-172-31-31-220.ec2.internal',
#     'PrivateIpAddress': '172.31.31.220',
#     'PrivateIpAddresses': [{'Association': {'IpOwnerId': 'amazon',
#        'PublicDnsName': 'ec2-34-207-151-86.compute-1.amazonaws.com',
#        'PublicIp': '34.207.151.86'},
#       'Primary': True,
#       'PrivateDnsName': 'ip-172-31-31-220.ec2.internal',
#       'PrivateIpAddress': '172.31.31.220'}],
#     'SourceDestCheck': True,
#     'Status': 'in-use',
#     'SubnetId': 'subnet-087f3c89ac49c4386',
#     'VpcId': 'vpc-0ea73b2740360fb3a',
#     'InterfaceType': 'interface'}],
#   'RootDeviceName': '/dev/xvda',
#   'RootDeviceType': 'ebs',
#   'SecurityGroups': [{'GroupName': 'launch-wizard-1',
#     'GroupId': 'sg-0ab6bec290e808f90'}],
#   'SourceDestCheck': True,
#   'Tags': [{'Key': 'Name', 'Value': 'test_instance'}],
#   'VirtualizationType': 'hvm',
#   'CpuOptions': {'CoreCount': 1, 'ThreadsPerCore': 1},
#   'CapacityReservationSpecification': {'CapacityReservationPreference': 'open'},
#   'HibernationOptions': {'Configured': False},
#   'MetadataOptions': {'State': 'applied',
#    'HttpTokens': 'optional',
#    'HttpPutResponseHopLimit': 1,
#    'HttpEndpoint': 'enabled',
#    'HttpProtocolIpv6': 'disabled',
#    'InstanceMetadataTags': 'disabled'},
#   'EnclaveOptions': {'Enabled': False},
#   'PlatformDetails': 'Linux/UNIX',
#   'UsageOperation': 'RunInstances',
#   'UsageOperationUpdateTime': datetime.datetime(2022, 5, 27, 20, 51, 51, tzinfo=tzutc()),
#   'PrivateDnsNameOptions': {'HostnameType': 'ip-name',
#    'EnableResourceNameDnsARecord': True,
#    'EnableResourceNameDnsAAAARecord': False},
#   'MaintenanceOptions': {'AutoRecovery': 'default'}}]

# %%
[i.get('Instances')[0]['SecurityGroups'][0] for i in base]
# Out:
# [{'GroupName': 'launch-wizard-4', 'GroupId': 'sg-0b9ae95a557e9e597'},
#  {'GroupName': 'launch-wizard-2', 'GroupId': 'sg-0835e10401540eaf0'},
#  {'GroupName': 'launch-wizard-1', 'GroupId': 'sg-0ab6bec290e808f90'}]

# %%
[i.get('Instances')[0]['SecurityGroups'][0].get('GroupId') for i in base]
# Out:
# ['sg-0b9ae95a557e9e597', 'sg-0835e10401540eaf0', 'sg-0ab6bec290e808f90']

# %%
def get_attached_security_groups() -> list:
    base = ec2.describe_instances().get('Reservations')
    return [i.get('Instances')[0]['SecurityGroups'][0].get('GroupId') for i in base]

# %%
get_attached_security_groups()
# Out:
# ['sg-0b9ae95a557e9e597', 'sg-0835e10401540eaf0', 'sg-0ab6bec290e808f90']

# %%
get_all_security_groups()
# Out:
# ['sg-0b9ae95a557e9e597',
#  'sg-0835e10401540eaf0',
#  'sg-0ab6bec290e808f90',
#  'sg-081f6c1a9d9d8cec0']

# %% [markdown]
# # -----------------------

# %% [markdown]
# ## ----- Steps for filter_unattached_sg()

# %%
def filter_unattached_sg() -> list:
    return list(filter(lambda group: group not in get_attached_security_groups(), get_all_security_groups()))

# %%
filter_unattached_sg()
# Out:
# ['sg-081f6c1a9d9d8cec0']

# %% [markdown]
# # -----------------------

# %%
if you run this command below it will delete your unsattached SGs

# %%
# def delete_unattached_sg(unattached_list):
# for sg in unattached_list:
#     try:
#         ec2.delete_security_group(GroupId=sg)
#     except Exception as e:
#         if '"default" cannot be deleted by a user' in str(e):
#             print("Unable to delete default security group")

# %%
# def init():
#     delete_unattached_sg(filter_unattached_sg())



# if __name__ == "__main__":
#     init()
